# %%
import pandas as pd
import numpy as np

# %%
madrid_bcn_data = pd.read_csv("Madrid_Barcelona_data_shortheader.csv")
madrid_bcn_data.head()
# Out:
#          Date Country    City Specie  count   min   max  median  variance
# 0  2020-09-02      ES  Madrid     o3     88   2.5  53.2    31.3   1257.14
# 1  2020-10-13      ES  Madrid     o3     90   1.7  39.8    19.1    885.83
# 2  2020-11-10      ES  Madrid     o3     90   0.5  22.0     4.5    452.15
# 3  2020-03-21      ES  Madrid     o3     96  17.5  32.9    26.1    139.13
# 4  2020-04-26      ES  Madrid     o3     93  13.0  37.0    26.2    512.67

# %%
madrid_bcn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8695 entries, 0 to 8694
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      8695 non-null   object
#  1   Country   8695 non-null   object
#  2   City      8695 non-null   object
#  3   Specie    8695 non-null   object
#  4   count     8695 non-null   int64
#  5   min       8695 non-null   float64
#  6   max       8695 non-null   float64
#  7   median    8695 non-null   float64
#  8   variance  8695 non-null   float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 611.5+ KB

# %%
# empty cells/ data?
madrid_bcn_data.isna().sum()
# Out:
# Date        0
# Country     0
# City        0
# Specie      0
# count       0
# min         0
# max         0
# median      0
# variance    0
# dtype: int64

# %%
madrid_bcn_data.Specie
# Out:
# 0               o3
# 1               o3
# 2               o3
# 3               o3
# 4               o3
#            ...
# 8690    wind-speed
# 8691    wind-speed
# 8692    wind-speed
# 8693    wind-speed
# 8694    wind-speed
# Name: Specie, Length: 8695, dtype: object

# %%
madrid_bcn_data.Specie.value_counts()
# Out:
# no2            774
# o3             774
# pm10           774
# co             773
# so2            759
# humidity       739
# temperature    739
# pressure       735
# dew            734
# wind-gust      602
# wind-speed     602
# pm25           387
# wind gust      152
# wind speed     151
# Name: Specie, dtype: int64

# %%
#list_species_pollution = madrid_bcn_data['Specie'].unique().tolist()
#for specie in list_species_pollution:
#    print(specie)

# Create df with Bcn data

df_bcn = madrid_bcn_data[madrid_bcn_data['City'] == 'Barcelona']
df_bcn
# Out:
#             Date Country       City      Specie  count  min   max  median  \
# 4543  2020-03-24      ES  Barcelona         so2     51  0.6   4.6     0.6
# 4544  2020-03-28      ES  Barcelona         so2    100  0.6   5.1     1.1
# 4545  2020-04-14      ES  Barcelona         so2    120  0.6  12.7     1.1
# 4546  2020-09-21      ES  Barcelona         so2     99  0.6   1.6     0.6
# 4547  2020-09-24      ES  Barcelona         so2    116  0.6   6.1     1.1
# ...          ...     ...        ...         ...    ...  ...   ...     ...
# 8690  2020-06-24      ES  Barcelona  wind-speed    261  0.1  13.1     2.3
# 8691  2020-09-01      ES  Barcelona  wind-speed    244  0.1  11.5     1.8
# 8692  2020-11-02      ES  Barcelona  wind-speed    176  0.1  12.2     1.5
# 8693  2020-12-06      ES  Barcelona  wind-speed    302  0.1  15.1     4.0
# 8694  2020-04-18      ES  Barcelona  wind-speed    295  0.1  11.5     3.4
#
#       variance
# 4543      6.83
# 4544      5.98
# 4545     73.29
# ...

# %%
df_bcn_specie = df_bcn[df_bcn.Specie.isin(['o3', 'pm10', 'no2', 'co', 'so2', 'pm25'])]
df_bcn_specie
# df_bcn_specie.Specie.value_counts()
# Out:
#             Date Country       City Specie  count  min   max  median  variance
# 4543  2020-03-24      ES  Barcelona    so2     51  0.6   4.6     0.6      6.83
# 4544  2020-03-28      ES  Barcelona    so2    100  0.6   5.1     1.1      5.98
# 4545  2020-04-14      ES  Barcelona    so2    120  0.6  12.7     1.1     73.29
# 4546  2020-09-21      ES  Barcelona    so2     99  0.6   1.6     0.6      1.09
# 4547  2020-09-24      ES  Barcelona    so2    116  0.6   6.1     1.1     12.04
# ...          ...     ...        ...    ...    ...  ...   ...     ...       ...
# 7288  2020-05-12      ES  Barcelona     o3    303  0.9  34.2    26.0    753.42
# 7289  2020-06-01      ES  Barcelona     o3    299  2.1  43.9    30.1   1112.81
# 7290  2020-07-05      ES  Barcelona     o3    310  0.9  48.0    25.6   1419.11
# 7291  2020-02-25      ES  Barcelona     o3    296  0.5  35.8    11.0   1132.84
# 7292  2020-02-27      ES  Barcelona     o3    284  4.1  33.3    24.8    409.36
#
# [1935 rows x 9 columns]

# %%
for i in df_bcn_specie.index:
    df_bcn_specie['Date'][i] =  df_bcn_specie['Date'][i][0:7]
    print(f"Fecha: {df_bcn_specie['Date'][i]} ")
# Out:
# <ipython-input-15-23882820ae41>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bcn_specie['Date'][i] =  df_bcn_specie['Date'][i][0:7]
# C:\Users\dgruh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3343: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Fecha: 2020-03
# Fecha: 2020-03
# Fecha: 2020-04
# Fecha: 2020-09
# Fecha: 2020-09
# Fecha: 2020-12
# Fecha: 2021-01
# Fecha: 2020-02
# Fecha: 2020-04
# Fecha: 2020-06
# Fecha: 2020-06
# Fecha: 2020-09
# Fecha: 2020-11
# Fecha: 2020-12
# Fecha: 2021-01
# Fecha: 2020-01
# Fecha: 2020-02
# ...

# %%
df_bcn_specie
# Out:
#          Date Country       City Specie  count  min   max  median  variance
# 4543  2020-03      ES  Barcelona    so2     51  0.6   4.6     0.6      6.83
# 4544  2020-03      ES  Barcelona    so2    100  0.6   5.1     1.1      5.98
# 4545  2020-04      ES  Barcelona    so2    120  0.6  12.7     1.1     73.29
# 4546  2020-09      ES  Barcelona    so2     99  0.6   1.6     0.6      1.09
# 4547  2020-09      ES  Barcelona    so2    116  0.6   6.1     1.1     12.04
# ...       ...     ...        ...    ...    ...  ...   ...     ...       ...
# 7288  2020-05      ES  Barcelona     o3    303  0.9  34.2    26.0    753.42
# 7289  2020-06      ES  Barcelona     o3    299  2.1  43.9    30.1   1112.81
# 7290  2020-07      ES  Barcelona     o3    310  0.9  48.0    25.6   1419.11
# 7291  2020-02      ES  Barcelona     o3    296  0.5  35.8    11.0   1132.84
# 7292  2020-02      ES  Barcelona     o3    284  4.1  33.3    24.8    409.36
#
# [1935 rows x 9 columns]

# %%
# Create df with Mad data

df_mad = madrid_bcn_data[madrid_bcn_data['City'] == 'Madrid']
df_mad
# Out:
#             Date Country    City Specie  count   min   max  median  variance
# 0     2020-09-02      ES  Madrid     o3     88   2.5  53.2    31.3   1257.14
# 1     2020-10-13      ES  Madrid     o3     90   1.7  39.8    19.1    885.83
# 2     2020-11-10      ES  Madrid     o3     90   0.5  22.0     4.5    452.15
# 3     2020-03-21      ES  Madrid     o3     96  17.5  32.9    26.1    139.13
# 4     2020-04-26      ES  Madrid     o3     93  13.0  37.0    26.2    512.67
# ...          ...     ...     ...    ...    ...   ...   ...     ...       ...
# 4538  2020-08-03      ES  Madrid    no2    206   0.5  24.7     4.6    216.22
# 4539  2020-07-26      ES  Madrid    no2    210   1.4  70.8     9.2   1395.77
# 4540  2020-08-23      ES  Madrid    no2    204   0.5  72.9     4.2   1095.60
# 4541  2020-10-08      ES  Madrid    no2    213   4.2  72.4    21.5   2302.88
# 4542  2021-01-18      ES  Madrid    no2    180  15.1  99.7    42.5   2378.29
#
# [4543 rows x 9 columns]

# %%
df_mad_specie = df_mad[df_mad.Specie.isin(['o3', 'pm10', 'no2', 'co', 'so2', 'pm25'])]
df_mad_specie
type('Date')
# Out:
# str
